# %%
import pandas as pd
import numpy as np
import cufflinks as cf
import plotly
import plotly.plotly as py
from sqlalchemy import create_engine
engine = create_engine('postgresql://localhost:5432/')
plotly.plotly.sign_in('alexderbes', 'jd1okjy9w5')
from sqlalchemy import create_engine

from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
from plotly.graph_objs import *
init_notebook_mode()

# %%
#pipeline = pd.read_excel('data/NJ_Solar_Pipeline_as_of_022916.xlsx', sheetname='Project List')
#engine = create_engine('postgresql://localhost:5432/')
#pipeline.to_sql('nj_current', engine)
#frm = pd.merge(inverters, totals, how='left', on='dte')
#frm['pct'] = frm['count_x'] / frm['count_y']
nj_pipeline=pd.read_sql_query("""select date_trunc('month', "Accepted Date"::date)::date, us_installer, count(1), sum("System Size") from nj_pipeline LEFT JOIN nj_installer_map on "Installer" = nj_installer group by date_trunc, us_installer order by date_trunc desc""", con=engine)
pivot = nj_pipeline.pivot(index='date_trunc', columns='us_installer', values='count')
plotly.offline.iplot([{
    'x': pivot.index,
    'y': pivot[col],
    'name': col
}  for col in pivot.columns])
# Out:
# <div id="7f7a3bff-1152-4a20-ac86-5ac0382169ea" style="height: 525; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7f7a3bff-1152-4a20-ac86-5ac0382169ea", [{"y": [null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 2.0, null, null, null, null, null], "x": [null, "2012-06-01", "2012-11-01", "2013-11-01", "2014-03-01", "2014-04-01", "2014-05-01", "2014-07-01", "2014-08-01", "2014-09-01", "2014-10-01", "2014-11-01", "2014-12-01", "2015-01-01", "2015-02-01", "2015-03-01", "2015-04-01", "2015-05-01", "2015-06-01", "2015-07-01", "2015-08-01", "2015-09-01", "2015-10-01", "2015-11-01", "2015-12-01", "2016-01-01", "2016-02-01"], "name": null}, {"y": [34.0, 1.0, 2.0, 5.0, 1.0, 10.0, 1.0, 2.0, 4.0, 4.0, 11.0, 14.0, 20.0, 21.0, 210.0, 219.0, 227.0, 242.0, 182.
# ...

# %%
#installs = pd.read_excel('data/NJ_Solar_Installations_as_of_022916.xlsx', sheetname='Project List')
#engine = create_engine('postgresql://localhost:5432/')
#installs.to_sql('nj_installs', engine)
nj_installs=pd.read_sql_query("""select date_trunc('month', "Accepted Date"::date)::date, us_installer, count(1), sum("System Size") from nj_installs LEFT JOIN nj_installer_map on "Installer" = nj_installer group by date_trunc, us_installer order by date_trunc desc""", con=engine)
pivot = nj_installs.pivot(index='date_trunc', columns='us_installer', values='count')
plotly.offline.iplot([{
    'x': pivot.index,
    'y': pivot[col],
    'name': col
}  for col in pivot.columns])
# Out:
# <div id="79462974-4534-4469-bb98-996f400392c3" style="height: 525; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("79462974-4534-4469-bb98-996f400392c3", [{"y": [1.0, 3.0, 5.0, 1.0, 4.0, 3.0, 1.0, 5.0, 4.0, 3.0, 1.0, 5.0, 5.0, 2.0, 2.0, 5.0, 8.0, 1.0, 2.0, 6.0, 8.0, 12.0, 19.0, 17.0, 9.0, 5.0, 14.0, 18.0, 11.0, 16.0, 7.0, 5.0, 10.0, 26.0, 22.0, 19.0, 18.0, 19.0, 16.0, 27.0, 18.0, 25.0, 13.0, 20.0, 43.0, 27.0, 70.0, 36.0, 38.0, 42.0, 67.0, 79.0, 54.0, 45.0, 1.0, 1.0, 109.0, 84.0, 42.0, 1.0, 1.0, 95.0, 21.0, 15.0, 5.0, 3.0, 53.0, 16.0, 5.0, 98.0, 70.0, 119.0, 67.0, 27.0, 17.0, 7.0, 53.0, null, 107.0, 78.0, 20.0, 15.0, 17.0, 19.0, 69.0, 11.0, 27.0, 105.0, 93.0, 64.0, 119.0, 86.0, 113.0, 59.0, 72.0, 106.0, 27.0, 87.0, 178.0, 124.0, 56.0, 174.0, 99.0, 57.0, 181.0, 125.0, 189.0, 139.0, 167.0, 355.0, 160.0, 197.0, 178.0, 269.0
# ...
